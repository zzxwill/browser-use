# %% [markdown]
# # Agent prompt
#
# ```
# You are web scraping agent. Your task is control the browser where for every step you get the current state and a list of actions you can take.
#
# Your task is:
# Apply for 50 jobs for software engineering in Zurich.
#
# Extra context:
# `
# Gregor Žunič
# gregorzunic.com
# gregor@profaile.com
# github.com/gregpr07
# linkedin.com/in/gregorzunic
# EDUCATION
# ETH Zurich 2022-2026
# MSc Data Science
# • First place in Advanced Machine Learning projects
# University of Ljubljana, Faculty of Mathematics and Physics BSc Physics
# • Bachelor thesis: GANs in particle physics
# INDUSTRY
# 2019-2022
# Spexia.ai 2023-2024
# Founder
# • The Easiest Way to Boost Your Organic Traffic
# Internal Discovery Platform 2023-2023
# Founder
# • Find what your company knows with RAG. Instantly.
# • Didn’t find product market fit
# Real Fake Photos 2023-2024
# Founder
# • Turn your selfies into professional headshots with AI
# • Built the app from 0 to 70k+ users
# • Heavy ML to improve stable diffusion
# Profaile GmbH 2023-2024
# Founder and CTO
# • Software and ML Consulting
# Flare Network 2022-2023
# Blockchain and Senior Fullstack Developer
# • Senior frontend and backend developer role.
# Idoru.capital 2021-2022
# Tech Lead
# • Idoru capital is the first crypto asset backed by Real World Assets
# Strader.io 2021-2021
# Co-Founder
# • DeFi/crypto startup for trading strategies
# Videolectures.NET (JSI Project) 2019-2021
# Tech Lead
# • Implemented the new Backend and Website and the Mobile App; apps have 20k users
# X5GON (JSI Project) 2018-2020
# ML Researcher & Fullstack developer
# • EU Horizon2020 project for connecting and analyzing OER resources from multiple repositories;
# led by Prof. John Shawe-Taylor
# • Started by collecting data from OER repositories which were analyzed and used to create a state-
# of-the-art cross-site recommendation system
# • X5GON Blind Backend and Frontend; sub-project focused on enhancing the learning experience
# of blind and partially blind people by providing a simplified interface and highly personalized
# recommendation engine
# • X5GON Platform and X5GON Blind website; project’s presentation website
# • X5GON Discovery website; UI for the state-of-the-art cross-site recommendation engine
# RESEARCH
# American Slovenian Education Foundation 2021-2023
# Junior Fellow
# University of California, Berkeley 07.2021-10.2021
# Student intern and ASEF fellow under the supervision of Prof. Dawn Song Remote
# • Cryptocurrency research; Researching EVM cross-chain empirical measurements focused on MEV
# • Model heuristics for detecting on-chain MEV
# Jožef Stefan Institute 06.2018-06.2022
# Student ML Researcher under the supervision of Prof. Dunja Mladenić Ljubljana, Slovenia
# • Machine Learning research; focused on Natural Language Processing with Transformers
# • Winner of Innovation IT&ML Hackaton; organized and hosted by Slovenian Post Office
# • Participated in AI for the Common Good F’AI’R Education Hackathon by British Embassy in Paris
# • Participated in X5GON hackathon on Open Education and AI; organized by X5gon, hosted at UCL
# • Reciever of JSI excellence scholarship
# PUBLICATIONS
# Žunič Gregor, Novak Erik. Hierarchical classification of educational resources. Data Mining and
# Data Warehouses - SiKDD, 5 October 2020.
# OTHER SKILLS
# KK Ježica 2018-present
# Semi-Professional Basketball Player Ljubljana, Slovenia
# • 5-th best scorer in University Basketball League (season 2019/2020)
# Helios Suns 2015-2018
# Semi-Professional Basketball Player Domžale, Slovenia
# General
# • Language Skills Slovene (mother tongue), English (C1 TOEFL: 107), French (A2), German (A1)
# • Guitar enthusiast (8 years primary school), Chess (participated in 2 youth world championships)
# `
#
# In every step, please only control the web browser with actions.
# Actions can also give you back follow up questions about the state of the website if your instructions are ambigous.
# ```

# %% [markdown]
# ## State prompt
#
# ```json
# {
#     state: {
#         "current_url": undefined,
#     },
#     actions: [
#         {
#             "type": "search_google",
#             "params": {
#                 "query": "string"
#             }
#         },
#         {
#             "type": "go_to_url",
#             "params": {
#                 "url": "string"
#             }
#         }
#     ]
# }
# ```

# %% [markdown]
# {
#   "type": "search_google",
#   "params": {
#     "query": "software engineering jobs in Zurich"
#   }
# }

# %% [markdown]
# ...

# %% [markdown]
# {
#     state: {
#         "current_url": undefined,
#     },
#     actions: [
#         {
#             "type": "search_google",
#             "params": {
#                 "query": "string"
#             }
#         },
#         {
#             "type": "go_to_url",
#             "params": {
#                 "url": "string"
#             }
#         }
#     ]
# }
